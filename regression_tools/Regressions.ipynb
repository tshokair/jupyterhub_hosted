# %%
import numpy as np
import os
import pandas as pd
import psycopg2
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn import preprocessing
from urllib.parse import urlparse
from urllib import parse
from lib.build_regressions_features_no_na import MixedFeatureData
from lib.explore_data import ExploratoryAnalysis
from lib.regressions_statsmodel import MixedClassificationModel, RegressionModel

# %matplotlib inline
FOLLOWER_URL = os.environ['FOLLOWER_URL']
                          
def make_connection():
    url_output = FOLLOWER_URL
    url = urlparse(url_output)
    conn = psycopg2.connect(
        database=url.path[1:],
        user=url.username,
        password=url.password,
        host=url.hostname
    )
    return conn

# %% [markdown]
# # START HERE
# ## The cell below contains all the mission specific data. Here you will specifity the mission id, the independent variables, the dependent variable, and the definitions of positive and negative outcome.

# %%
# CHANGE THESE VALUES
mission_id = "25614"
# ONLY USE SINGLE QUESTIONS FOR DEPENDENT AND INDEPENDENT VARIABLES IN FORMAT 'PART_NUM-QUESTION_NUM'
# ALL "4-4", "4-5","4-6", "4-10","4-11","4-12", "4-13","4-14","4-15","4-17","4-18","4-19","4-21"
continuous_independent_variables = [
    "4-4", "4-5","4-6", "4-10","4-11","4-12", 
    "4-13","4-14","4-15","4-17","4-18","4-19",
]
# NOTE MULTIPLE QUESTIONS NEED TO BE CATEGORICAL
categorical_independent_variables = ["4-21"]
binary_independent_variables = []
dependent_variable = "4-2"
negative_outcomes = [
"Moderately satisfied",
"Slightly satisfied",
"Neither satisfied nor dissatisfied",
"Slightly dissatisfied",
"Moderately dissatisfied",
"Extremely dissatisfied"
]
positive_outcomes = ["Extremely satisfied"]
demo_independent_variables = []
tag_independent_variables = []
#mutually exclusive scout groups only at this time
scout_group_independent_variables = []
#response_data = pd.read_pickle("mission_" + mission_id + "_data.pkl")
question_response_filtering = {}
grouping = 'user_id'
ethnicity_filters = []
education_filters = []
tag_filters = []
scout_group_filters = ["Apple","Samsung","Pixel","Bose"]

# %% [markdown]
# # After entering the information above, go to Cell -> Run All to see your regression results

# %%
cnc = make_connection()
questions = pd.read_sql_query(
    """with m_questions as (select id as question_id, label, type, position as question_position,
                            part_id, structure from questions where type in 
                            ('SingleQuestion', 'MultipleQuestion', 'NumberQuestion')
                            and mission_id = """
    + mission_id
    + """),
       m_parts as (select id as part_id, position as part_position from parts where
                   mission_id = """
    + mission_id
    + """)
    select question_id, label, type, question_position, m_parts.part_id, part_position,
    structure from m_questions join m_parts on m_questions.part_id = m_parts.part_id""",
    cnc,
)
print("collected questions")

question_list = (
    "(" + ",".join([str(a) for a in questions["question_id"].tolist()]) + ")"
)
snippets = pd.read_sql_query(
    """select id as snippet_id, user_id, assignment_id from snippets where mission_id = """
    + mission_id,
    cnc,
)
print("collected snippets")
scout_group_names = (
    "("
    + ",".join(["'" + str(sg) + "'" for sg in scout_group_independent_variables])
    + ")"
)
assignments = pd.read_sql_query(
    """select id as assignment_id, user_id from assignments where 
          mission_id = """
    + mission_id
    ,cnc)
assignment_list = "(" + ','.join([str(aid) for aid in assignments['assignment_id'].unique()]) +")"
assignment_groups = pd.read_sql_query(
    """select assignment_id, scout_group_id from assignments_scout_groups
    where assignment_id in """ + assignment_list,
    cnc
)
groups = pd.read_sql_query(
    """select id as scout_group_id, name as scout_group from scout_groups
    """,
    cnc)
scout_groups = pd.merge(
    assignment_groups,
    groups[groups['scout_group'].isin(scout_group_filters)],
    on='scout_group_id'
)
print("collected scout groups")


snippet_list = (
    "(" + ",".join([str(a) for a in snippets["snippet_id"].tolist()]) + ")"
)
responses = pd.read_sql_query(
    """select  id as response_id, snippet_id, question_id, 
    answers from responses where snippet_id in """
    + snippet_list,
    cnc,
)
print("collected responses")
snippets_tags = pd.read_sql_query(
    """Select tag_id, snippet_id from snippets_tags where snippet_id in """
    + snippet_list,
    cnc,
)
tag_list = "(" + ",".join([str(a) for a in snippets_tags["tag_id"].tolist()]) + ")"
tags = pd.read_sql_query(
    """select id as tag_id, name as tag from tags where id in """ + tag_list, cnc
)

snippets_tags = pd.merge(snippets_tags, tags, on="tag_id")
tagged_snippets = pd.merge(snippets, snippets_tags, on="snippet_id", how="left")
user_list = "(" + ",".join([str(a) for a in assignments["user_id"].tolist()]) + ")"
users = pd.read_sql_query(
    """select id as user_id, ethnicity, education, household_income, birthday, gender from users where
                                 id in """
    + user_list,
    cnc,
)
user_snippets = pd.merge(tagged_snippets, users, on="user_id", how="left")
user_snippets = pd.merge(user_snippets, scout_groups, on="assignment_id", how="left")
response_data = pd.merge(responses, questions, on="question_id")
response_data = pd.merge(response_data, user_snippets, on="snippet_id", how="left")
cnc.close
# Out:
# collected questions
# collected snippets
# collected scout groups
# collected responses
# <function connection.close>

# %%
#response_data.to_pickle('mission_'+mission_id+'_data.pkl')

# %%
response_data['birthday'] = response_data['birthday'].astype('datetime64[ns]')

# %%
if ethnicity_filters:
    ethnicities = ethnicity_filters
else:
    response_data['ethnicity'] = (
        response_data['ethnicity'].fillna('missing')
    )
    ethnicities = response_data['ethnicity'].unique()

if education_filters:
    educations = education_filters
else:
    response_data['education'] = (
        response_data['education'].fillna('missing')
    )
    educations = response_data['education'].unique()
if tag_filters:
    tags = tag_filters
else:
    response_data['tag'] = (
        response_data['tag'].fillna('None')
    )
    tags = response_data['tag'].unique()
if scout_group_filters:
    scout_groups = scout_group_filters
else:
    response_data['scout_group'] = (
        response_data['scout_group'].fillna('None')
    )
    scout_groups = response_data['scout_group'].unique()
filtered = response_data[(response_data['ethnicity'].isin(ethnicities)) & 
                        (response_data['education'].isin(educations)) &
                        (response_data['tag'].isin(tags)) &
                        (response_data['scout_group'].isin(scout_groups))].copy()
filtered_id_list = []
for question in question_response_filtering:
    part, num = int(question.split('-')[0])-1, int(question.split('-')[1])-1
    response = question_response_filtering[question]
    ids = filtered [(filtered['part_position'] == part) &
                        (filtered['question_position'] == num) &
                        (any([response in x for x in filtered['answers']]))][grouping].unique()
    filtered_id_list = filtered_id_list + list(ids)

# %%
if filtered_id_list:
    filtered_all = filtered[filtered["snippet_id"].isin(filtered_id_list)].copy()
else:
    filtered_all = filtered.copy()

# %%
print(len(response_data[response_data['part_position'] == 3].groupby('user_id').count()))
print(len(filtered[filtered['part_position'] == 3].groupby('user_id').count()))
print(len(filtered[filtered['part_position'] == 3].drop_duplicates(['user_id','question_id']).groupby(['user_id']).count()))
# Out:
# 927
# 927
# 927

# %%
filtered[filtered['part_position'] == 3].groupby('user_id').first().reset_index().groupby('scout_group').count()
# Out:
#              user_id  response_id  snippet_id  question_id  answers  label  \
# scout_group
# Apple            235          235         235          235      235    235
# Bose             228          228         228          228      228    228
# Pixel            228          228         228          228      228    228
# Samsung          236          236         236          236      236    236
#
#              type  question_position  part_id  part_position  structure  \
# scout_group
# Apple         235                235      235            235        235
# Bose          228                228      228            228        228
# Pixel         228                228      228            228        228
# Samsung       236                236      236            236        236
#
#              assignment_id  tag_id  tag  ethnicity  education  \
# scout_group
# Apple                  235       0  235        235        235
# Bose                   228       0  228        228        228
# Pixel                  228       0  228        228        228
# Samsung                236       0  236        236        236
#
#              household_income  birthday  gender  scout_group_id
# scout_group
# Apple                     210       235     235             235
# Bose                      216       228     228             228
# Pixel                     218       227     227             228
# Samsung                   226       236     236             236

# %%
fd = MixedFeatureData(
    filtered_all,
    dependent_variable,
    continuous_independent_variables,
    binary_independent_variables,
    categorical_independent_variables,
    positive_outcomes,
    negative_outcomes,
    demo_independent_variables,
    tag_independent_variables,
    scout_group_independent_variables,
    grouping,
)
eda = ExploratoryAnalysis(
    fd.encoded_features,
    fd.independent_variables,
    fd.dependent_variable,
    fd.question_choices(),
)
logistic_regression = MixedClassificationModel(fd)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.399076
#          Iterations 14

# %%
fd.raw['scout_group'].unique()
# Out:
# array(['Pixel', 'Bose', 'Samsung', 'Apple'], dtype=object)

# %%
len(logistic_regression.balanced)
# Out:
# 428

# %% [markdown]
# ## Correlations of Independent Variables
# ### After viewing these you may want to rethink your independent variable choices

# %%
eda.correlation_matrix_plots()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12e69a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13740c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120be3048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1373976d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13594bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a31e5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128944f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd20940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd20978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1298d9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1298fd518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f850e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127002828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1296c51d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128d42b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1286214e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128895e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129bb47b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128750160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1285c7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129642470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128652dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1297f0780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127bb3128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127c80a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122b44438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1299ddda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1296fb748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127c240f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122b79a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127b32400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127b62d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128807710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127ced0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b1afa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127be33c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12869ed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1297336d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1286d8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1104239e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110430390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135db2cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135def6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132dcb048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13564a9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x135634358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130864cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13085b668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13743bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137422978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13585a320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13583fc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f812630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f7ebf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137387940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1373a92e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ee8c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ec15f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135e9ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135e7f908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x135ebb2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135ee4c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1373105c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137307f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135963748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135940c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132e1dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132dfd588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132e21ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130a66898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130a42dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cbbeba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cbed550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1356d5eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1356b4860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x135d34208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135d16b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f82e518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f84ae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135e42828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135e631d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137348b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1373764e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1356f2e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1357157f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ce85198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ce5bb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135c4d4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135c2ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ff47b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x133017160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ff6ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bb6e470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bb8add8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122e6e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122e90128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122eaba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122eca438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122ee6da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122f05748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122f5f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122f7ba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123371400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12338ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124392710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1243b10b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1243cca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1243ec3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124406d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264176d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126438080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264519e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126473390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12648dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264ae6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264ce048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264e89b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126509358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126526cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126545668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12655ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12657f978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265a1320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265bcc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265db630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265f7f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126617940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266382e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126652c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266725f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12668ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266ae908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266cf2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266e9c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267095c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126724f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267448d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126765278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126780be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267a1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267bbef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267db898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267fe240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126817ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126837550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126853eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126871860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126893208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1268afb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126f52518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126f6fe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126f8e828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126faf1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126fcbb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126fea4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12720ee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12722e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a429198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a442b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a7404a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a75ce10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a77b7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a79c160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a7b7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a7d6470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a7f1dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a813780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a834128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a84fa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a86f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a888da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a8a9748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a8c90f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a8e3a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a905400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a921d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a940710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a9610b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a97ca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a996a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a9b6908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a9d62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a9f3c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa175c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa35f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa578d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa7b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aa99be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aabb588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aadaef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12aafe898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ab22240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ab3fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ab64550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ad4eeb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ad71860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ad95208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12adb3b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12add6518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12adf5e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ae17828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ae3b1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b09bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b0bc4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b0dbe48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b1007f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b1e0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b1feb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b2214a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b23ee10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12b2617b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b285160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b2a3ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b2c8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b2e5dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b308780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b32d128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b34aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b36c438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b38bda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b3ae748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b3d40f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b3f1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b414400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b430d68>]],
#       dtype=object)

# %%
eda.correlation_matrix()
# Out:
# question_name                                            4-4       4-5  \
# question_name
# 4-4                                                 1.000000  0.666301
# 4-5                                                 0.666301  1.000000
# 4-6                                                 0.412858  0.788879
# 4-10                                                0.320736  0.306163
# 4-11                                                0.211781  0.227757
# 4-12                                                0.258043  0.286910
# 4-13                                                0.257848  0.317664
# 4-14                                                0.331506  0.325675
# 4-15                                                0.256354  0.267711
# 4-17                                                0.227235  0.308626
# 4-18                                                0.285331  0.318397
# 4-19                                                0.617946  0.679625
# 4-21_Just right -- I’m satisfied with how deepl...  0.386854  0.480670
# 4-21_Too deep -- I’d prefer them not to go as d... -0.056023 -0.084251
# 4-21_Too shallow -- I’d prefer them to go more ... -0.399485 -0.485886
# outcome                                             0.405836  0.509738
#
# question_name                                            4-6      4-10  \
# question_name
# 4-4                                                 0.412858  0.320736
# 4-5                                                 0.788879  0.306163
# 4-6                                                 1.000000  0.275969
# 4-10                                                0.275969  1.000000
# 4-11                                                0.169978  0.264288
# 4-12                                                0.260053  0.330249
# 4-13                                                0.293021  0.372883
# 4-14                                                0.289711  0.321818
# 4-15                                                0.224416  0.272058
# 4-17                                                0.243606  0.255460
# 4-18                                                0.316861  0.398631
# 4-19                                                0.523893  0.392737
# 4-21_Just right -- I’m satisfied with how deepl...  0.332792  0.108175
# 4-21_Too deep -- I’d prefer them not to go as d... -0.129258 -0.012485
# 4-21_Too shallow -- I’d prefer them to go more ... -0.285642 -0.113984
# outcome                                             0.490699  0.435092
#
# question_name                                           4-11      4-12  \
# question_name
# 4-4                                                 0.211781  0.258043
# 4-5                                                 0.227757  0.286910
# 4-6                                                 0.169978  0.260053
# 4-10                                                0.264288  0.330249
# 4-11                                                1.000000  0.425226
# 4-12                                                0.425226  1.000000
# 4-13                                                0.528000  0.480011
# 4-14                                                0.217328  0.327074
# 4-15                                                0.252897  0.267870
# 4-17                                                0.341213  0.225512
# 4-18                                                0.170028  0.194618
# 4-19                                                0.225956  0.229726
# 4-21_Just right -- I’m satisfied with how deepl...  0.130975  0.181896
# 4-21_Too deep -- I’d prefer them not to go as d... -0.032224 -0.048104
# 4-21_Too shallow -- I’d prefer them to go more ... -0.125764 -0.172261
# outcome                                             0.264456  0.340088
#
# question_name                                           4-13      4-14  \
# question_name
# 4-4                                                 0.257848  0.331506
# 4-5                                                 0.317664  0.325675
# 4-6                                                 0.293021  0.289711
# 4-10                                                0.372883  0.321818
# 4-11                                                0.528000  0.217328
# 4-12                                                0.480011  0.327074
# 4-13                                                1.000000  0.287783
# 4-14                                                0.287783  1.000000
# 4-15                                                0.262430  0.252164
# 4-17                                                0.364053  0.139069
# 4-18                                                0.306017  0.286768
# 4-19                                                0.301651  0.301939
# 4-21_Just right -- I’m satisfied with how deepl...  0.229282  0.115964
# 4-21_Too deep -- I’d prefer them not to go as d... -0.083040 -0.087165
# 4-21_Too shallow -- I’d prefer them to go more ... -0.201101 -0.069386
# outcome                                             0.346984  0.291027
#
# question_name                                           4-15      4-17  \
# question_name
# 4-4                                                 0.256354  0.227235
# 4-5                                                 0.267711  0.308626
# 4-6                                                 0.224416  0.243606
# 4-10                                                0.272058  0.255460
# 4-11                                                0.252897  0.341213
# 4-12                                                0.267870  0.225512
# 4-13                                                0.262430  0.364053
# 4-14                                                0.252164  0.139069
# 4-15                                                1.000000  0.288190
# 4-17                                                0.288190  1.000000
# 4-18                                                0.181925  0.355439
# 4-19                                                0.337329  0.375167
# 4-21_Just right -- I’m satisfied with how deepl...  0.193477  0.253508
# 4-21_Too deep -- I’d prefer them not to go as d... -0.096906 -0.063715
# 4-21_Too shallow -- I’d prefer them to go more ... -0.150492 -0.242459
# outcome                                             0.316256  0.340922
#
# question_name                                           4-18      4-19  \
# question_name
# 4-4                                                 0.285331  0.617946
# 4-5                                                 0.318397  0.679625
# 4-6                                                 0.316861  0.523893
# 4-10                                                0.398631  0.392737
# 4-11                                                0.170028  0.225956
# 4-12                                                0.194618  0.229726
# 4-13                                                0.306017  0.301651
# 4-14                                                0.286768  0.301939
# 4-15                                                0.181925  0.337329
# 4-17                                                0.355439  0.375167
# 4-18                                                1.000000  0.435261
# 4-19                                                0.435261  1.000000
# 4-21_Just right -- I’m satisfied with how deepl...  0.218307  0.420818
# 4-21_Too deep -- I’d prefer them not to go as d... -0.107950 -0.073986
# 4-21_Too shallow -- I’d prefer them to go more ... -0.170802 -0.425222
# outcome                                             0.345337  0.493761
#
# question_name                                       4-21_Just right -- I’m satisfied with how deeply they went into my ear canal  \
# question_name
# 4-4                                                                                          0.386854
# 4-5                                                                                          0.480670
# 4-6                                                                                          0.332792
# 4-10                                                                                         0.108175
# 4-11                                                                                         0.130975
# 4-12                                                                                         0.181896
# 4-13                                                                                         0.229282
# 4-14                                                                                         0.115964
# 4-15                                                                                         0.193477
# 4-17                                                                                         0.253508
# 4-18                                                                                         0.218307
# 4-19                                                                                         0.420818
# 4-21_Just right -- I’m satisfied with how deepl...                                           1.000000
# 4-21_Too deep -- I’d prefer them not to go as d...                                          -0.493944
# 4-21_Too shallow -- I’d prefer them to go more ...                                          -0.782783
# outcome                                                                                      0.376953
#
# question_name                                       4-21_Too deep -- I’d prefer them not to go as deeply into my ear canal  \
# question_name
# 4-4                                                                                         -0.056023
# 4-5                                                                                         -0.084251
# 4-6                                                                                         -0.129258
# 4-10                                                                                        -0.012485
# 4-11                                                                                        -0.032224
# 4-12                                                                                        -0.048104
# 4-13                                                                                        -0.083040
# 4-14                                                                                        -0.087165
# 4-15                                                                                        -0.096906
# 4-17                                                                                        -0.063715
# 4-18                                                                                        -0.107950
# 4-19                                                                                        -0.073986
# 4-21_Just right -- I’m satisfied with how deepl...                                          -0.493944
# 4-21_Too deep -- I’d prefer them not to go as d...                                           1.000000
# 4-21_Too shallow -- I’d prefer them to go more ...                                          -0.154431
# outcome                                                                                     -0.149360
#
# question_name                                       4-21_Too shallow -- I’d prefer them to go more deeply into my ear canal  \
# question_name
# 4-4                                                                                         -0.399485
# 4-5                                                                                         -0.485886
# 4-6                                                                                         -0.285642
# 4-10                                                                                        -0.113984
# 4-11                                                                                        -0.125764
# 4-12                                                                                        -0.172261
# 4-13                                                                                        -0.201101
# 4-14                                                                                        -0.069386
# 4-15                                                                                        -0.150492
# 4-17                                                                                        -0.242459
# 4-18                                                                                        -0.170802
# 4-19                                                                                        -0.425222
# 4-21_Just right -- I’m satisfied with how deepl...                                          -0.782783
# 4-21_Too deep -- I’d prefer them not to go as d...                                          -0.154431
# 4-21_Too shallow -- I’d prefer them to go more ...                                           1.000000
# outcome                                                                                     -0.321435
#
# question_name                                        outcome
# question_name
# 4-4                                                 0.405836
# 4-5                                                 0.509738
# 4-6                                                 0.490699
# 4-10                                                0.435092
# 4-11                                                0.264456
# 4-12                                                0.340088
# 4-13                                                0.346984
# 4-14                                                0.291027
# 4-15                                                0.316256
# 4-17                                                0.340922
# 4-18                                                0.345337
# 4-19                                                0.493761
# 4-21_Just right -- I’m satisfied with how deepl...  0.376953
# 4-21_Too deep -- I’d prefer them not to go as d... -0.149360
# 4-21_Too shallow -- I’d prefer them to go more ... -0.321435
# outcome                                             1.000000

# %%
def get_age_today(birthday):
    if birthday is not None:
        today =  datetime.datetime.today()
        #print(today, birthday)
        try:
            return (today - birthday).days/365.25
        except TypeError:
            return (today.date() - birthday).days/365.25
    return -1    

import datetime
filtered_all['age'] = filtered_all.apply(lambda row: get_age_today(row['birthday']), axis=1)
raw_copy = fd.raw.copy()
#raw_copy['birthday'] = raw_copy['birthday'].astype('datetime64[ns]')
#raw_copy['age'] = raw_copy.apply(lambda row: get_age_today(row['birthday']), axis=1)

# %% [markdown]
# # Relative Variance

# %%
explained_variances = eda.pca_explained_variances()
for i, q_id in enumerate(fd.independent_variables):
    print(q_id, round(explained_variances[i],2))
# Out:
# 4-4 0.4
# 4-5 0.13
# 4-6 0.08
# 4-10 0.07
# 4-11 0.06
# 4-12 0.05
# 4-13 0.05
# 4-14 0.04
# 4-15 0.04
# 4-17 0.03
# 4-18 0.03
# 4-19 0.01
# 4-21_Just right -- I’m satisfied with how deeply they went into my ear canal 0.01
# 4-21_Too deep -- I’d prefer them not to go as deeply into my ear canal 0.0
# 4-21_Too shallow -- I’d prefer them to go more deeply into my ear canal 0.0

# %% [markdown]
# # Single Value Decomposition
# ## Data Projected onto a 2D space, and colored by Outcome

# %%
eda.plot_outcome_clusters()

# %% [markdown]
# # Logistic Regression
# ## Histogram of Predicted Probability of Positive Outcome, colored by Actual Outcome

# %%
logistic_regression.visualize_goodness()

# %% [markdown]
# #
# ## Results Summary

# %%
logistic_regression.print_results()
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                outcome   No. Observations:                  428
# Model:                          Logit   Df Residuals:                      414
# Method:                           MLE   Df Model:                           13
# Date:                Tue, 11 Dec 2018   Pseudo R-squ.:                  0.4243
# Time:                        10:18:52   Log-Likelihood:                -170.80
# converged:                       True   LL-Null:                       -296.67
#                                         LLR p-value:                 2.806e-46
# ================================================================================================================================================
#                                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------
# 4-4                                                                              0.4297      0.238      1.805      0.071      -0.037       0.896
# 4-5                                                                              0.3986      0.354      1.126      0.260      -0.295       1.092
# 4-6                                                                              0.6372      0.269      2.369      0.018       0.110       1.164
# 4-10                                                                             0.6785      0.167      4.070      0.000       0.352       1.005
# 4-11                                                                            -0.0556      0.166     -0.334      0.738      -0.382       0.270
# 4-12                                                                             0.3508      0.187      1.873      0.061      -0.016       0.718
# 4-13                                                                             0.2523      0.190      1.328      0.184      -0.120       0.625
# 4-14                                                                             0.2535      0.159      1.594      0.111      -0.058       0.565
# 4-15                                                                             0.2888      0.156      1.851      0.064      -0.017       0.595
# 4-17                                                                             0.3457      0.190      1.823      0.068      -0.026       0.717
# 4-18                                                                             0.0273      0.175      0.156      0.876      -0.316       0.371
# 4-19                                                                             0.2125      0.206      1.032      0.302      -0.191       0.616
# 4-21_Just right -- I’m satisfied with how deeply they went into my ear canal     0.1947        nan        nan        nan         nan         nan
# 4-21_Too deep -- I’d prefer them not to go as deeply into my ear canal          -0.1386        nan        nan        nan         nan         nan
# 4-21_Too shallow -- I’d prefer them to go more deeply into my ear canal         -0.1220        nan        nan        nan         nan         nan
# ================================================================================================================================================
# /usr/local/lib/python3.7/site-packages/statsmodels/base/model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %% [markdown]
# # Odds Ratios
# ## The percent increase in the probabibility of a positive outcome for each standard deviation of increase of the independent variable

# %%
logistic_regression.odds_ratio()
# Out:
# independent_variable  odds_%_increase        mu       std
#                                               4-4               54  5.230444  1.285415
#                                               4-5               49  4.926004  1.491793
#                                               4-6               89  4.839323  1.511109
#                                              4-10               97  5.418605  1.538432
#                                              4-11               -5  5.078224  1.451260
#                                              4-12               42  5.418605  1.017970
#                                              4-13               29  6.061311  1.395530
#                                              4-14               29  6.247357  1.228251
#                                              4-15               33  5.192389  1.234645
#                                              4-17               41  5.243129  1.309224
#                                              4-18                3  4.695560  1.393204
#                                              4-19               24  5.697674  1.538880
# 4-21_Just right -- I’m satisfied with how deep...               21  0.714588  0.452089
# 4-21_Too deep -- I’d prefer them not to go as ...              -13  0.088795  0.284749
# 4-21_Too shallow -- I’d prefer them to go more...              -11  0.196617  0.397861

# %% [markdown]
# #
# ## Simulated Probability of Positive Outcome controlling for all but one variable

# %%
for independent_variable in fd.continuous_independent_variables:
    if independent_variable not in fd.binary_independent_variables:
        logistic_regression.simulate_continuous_outcomes(independent_variable)

# %%
for independent_variable in fd.independent_variables:
    if independent_variable in fd.binary_independent_variables or\
       independent_variable in fd.dummies:
        logistic_regression.simulate_binary_outcomes(independent_variable)
